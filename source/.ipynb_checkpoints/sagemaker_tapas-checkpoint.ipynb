# %% [markdown]
# # Deploy a pretrained PyTorch BERT model from HuggingFace on Amazon SageMaker with Neuron container

# %% [markdown]
# ## Overview

# %% [markdown]
# In this tutotial we will deploy on SageMaker a pretraine BERT Base model from HuggingFace Transformers, using the [AWS Deep Learning Containers](https://github.com/aws/deep-learning-containers). We will use the same model as shown in the [Neuron Tutorial "PyTorch - HuggingFace Pretrained BERT Tutorial"](../../../../frameworks/torch/torch-neuronx/tutorials/training/bert.html#). We will compile the model and build a custom AWS Deep Learning Container, to include the HuggingFace Transformers Library.
#
# This Jupyter Notebook should run on a ml.c5.4xlarge SageMaker Notebook instance. You can set up your SageMaker Notebook instance by following the [Get Started with Amazon SageMaker Notebook Instances](https://docs.aws.amazon.com/sagemaker/latest/dg/gs-console.html) documentation.
#
# > We recommend increasing the size of the base root volume of you SM notebook instance, to accomodate the models and containers built locally. A root volume of 10Gb should suffice.

# %% [markdown]
# ## Install Dependencies:

# %% [markdown]
# This tutorial requires the following pip packages:

# %% [markdown]
# - torch-neuron
# - neuron-cc[tensorflow]
# - transformers

# %%
# !pip install --upgrade --no-cache-dir torch-neuron neuron-cc[tensorflow] torchvision torch --extra-index-url=https://pip.repos.neuron.amazonaws.com
# !pip install --upgrade --no-cache-dir 'transformers==4.6.0'
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com, https://pip.repos.neuron.amazonaws.com
# Requirement already satisfied: torch-neuron in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (1.13.1.2.7.1.0)
# Requirement already satisfied: neuron-cc[tensorflow] in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (1.15.0.0+eec0c3604)
# Requirement already satisfied: torchvision in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (0.14.1)
# Requirement already satisfied: torch in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (1.13.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from torch) (11.7.99)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from torch) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from torch) (11.10.3.66)
# Requirement already satisfied: typing-extensions in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from torch) (4.4.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from torch) (11.7.99)
# Requirement already satisfied: wheel in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (0.38.4)
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (65.6.3)
# Requirement already satisfied: islpy<=2022.1.1,>2021.1 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from neuron-cc[tensorflow]) (2022.1.1)
# Requirement already satisfied: protobuf<=3.20.1 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from neuron-cc[tensorflow]) (3.20.1)
# Requirement already satisfied: numpy<2,>=1.13.3 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from neuron-cc[tensorflow]) (1.18.5)
# Requirement already satisfied: dmlc-nnvm==1.15.0.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from neuron-cc[tensorflow]) (1.15.0.0+0)
# Requirement already satisfied: dmlc-topi==1.15.0.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from neuron-cc[tensorflow]) (1.15.0.0+0)
# Requirement already satisfied: inferentia-hwm==1.14.1.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from neuron-cc[tensorflow]) (1.14.1.0+a9fb5c73a)
# Requirement already satisfied: dmlc-tvm==1.15.0.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from neuron-cc[tensorflow]) (1.15.0.0+0)
# Requirement already satisfied: scipy<2 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from neuron-cc[tensorflow]) (1.7.3)
# Requirement already satisfied: networkx<=2.6.3 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from neuron-cc[tensorflow]) (2.6.3)
# Requirement already satisfied: tensorflow<2 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from neuron-cc[tensorflow]) (1.15.5)
# Requirement already satisfied: decorator in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from dmlc-topi==1.15.0.0->neuron-cc[tensorflow]) (5.1.1)
# Requirement already satisfied: attrs in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from dmlc-tvm==1.15.0.0->neuron-cc[tensorflow]) (22.2.0)
# Requirement already satisfied: requests in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from torchvision) (2.28.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from torchvision) (9.4.0)
# Requirement already satisfied: pytest>=2 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from islpy<=2022.1.1,>2021.1->neuron-cc[tensorflow]) (7.3.1)
# Requirement already satisfied: grpcio>=1.8.6 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from tensorflow<2->neuron-cc[tensorflow]) (1.54.2)
# Requirement already satisfied: absl-py>=0.7.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from tensorflow<2->neuron-cc[tensorflow]) (1.4.0)
# Requirement already satisfied: google-pasta>=0.1.6 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from tensorflow<2->neuron-cc[tensorflow]) (0.2.0)
# Requirement already satisfied: tensorflow-estimator==1.15.1 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from tensorflow<2->neuron-cc[tensorflow]) (1.15.1)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from tensorflow<2->neuron-cc[tensorflow]) (1.1.2)
# Requirement already satisfied: tensorboard<1.16.0,>=1.15.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from tensorflow<2->neuron-cc[tensorflow]) (1.15.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from tensorflow<2->neuron-cc[tensorflow]) (2.3.0)
# Requirement already satisfied: six>=1.10.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from tensorflow<2->neuron-cc[tensorflow]) (1.16.0)
# Requirement already satisfied: gast==0.2.2 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from tensorflow<2->neuron-cc[tensorflow]) (0.2.2)
# Requirement already satisfied: h5py<=2.10.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from tensorflow<2->neuron-cc[tensorflow]) (2.10.0)
# Requirement already satisfied: wrapt>=1.11.1 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from tensorflow<2->neuron-cc[tensorflow]) (1.15.0)
# Requirement already satisfied: astor>=0.6.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from tensorflow<2->neuron-cc[tensorflow]) (0.8.1)
# Requirement already satisfied: keras-applications>=1.0.8 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from tensorflow<2->neuron-cc[tensorflow]) (1.0.8)
# Requirement already satisfied: opt-einsum>=2.3.2 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from tensorflow<2->neuron-cc[tensorflow]) (3.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from requests->torchvision) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from requests->torchvision) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from requests->torchvision) (1.26.8)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from pytest>=2->islpy<=2022.1.1,>2021.1->neuron-cc[tensorflow]) (1.0.0)
# Requirement already satisfied: importlib-metadata>=0.12 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from pytest>=2->islpy<=2022.1.1,>2021.1->neuron-cc[tensorflow]) (4.11.4)
# Requirement already satisfied: packaging in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from pytest>=2->islpy<=2022.1.1,>2021.1->neuron-cc[tensorflow]) (21.3)
# Requirement already satisfied: tomli>=1.0.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from pytest>=2->islpy<=2022.1.1,>2021.1->neuron-cc[tensorflow]) (2.0.1)
# Requirement already satisfied: iniconfig in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from pytest>=2->islpy<=2022.1.1,>2021.1->neuron-cc[tensorflow]) (2.0.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from pytest>=2->islpy<=2022.1.1,>2021.1->neuron-cc[tensorflow]) (1.1.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow<2->neuron-cc[tensorflow]) (2.2.2)
# Requirement already satisfied: markdown>=2.6.8 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from tensorboard<1.16.0,>=1.15.0->tensorflow<2->neuron-cc[tensorflow]) (3.4.3)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from importlib-metadata>=0.12->pytest>=2->islpy<=2022.1.1,>2021.1->neuron-cc[tensorflow]) (3.11.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from werkzeug>=0.11.15->tensorboard<1.16.0,>=1.15.0->tensorflow<2->neuron-cc[tensorflow]) (2.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from packaging->pytest>=2->islpy<=2022.1.1,>2021.1->neuron-cc[tensorflow]) (3.0.9)
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Requirement already satisfied: transformers==4.6.0 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (4.6.0)
# Requirement already satisfied: numpy>=1.17 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from transformers==4.6.0) (1.18.5)
# Requirement already satisfied: regex!=2019.12.17 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from transformers==4.6.0) (2022.10.31)
# Requirement already satisfied: sacremoses in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from transformers==4.6.0) (0.0.53)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from transformers==4.6.0) (0.10.3)
# Requirement already satisfied: importlib-metadata in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from transformers==4.6.0) (4.11.4)
# Requirement already satisfied: tqdm>=4.27 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from transformers==4.6.0) (4.64.1)
# Requirement already satisfied: requests in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from transformers==4.6.0) (2.28.1)
# Requirement already satisfied: packaging in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from transformers==4.6.0) (21.3)
# Requirement already satisfied: huggingface-hub==0.0.8 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from transformers==4.6.0) (0.0.8)
# Requirement already satisfied: filelock in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from transformers==4.6.0) (3.9.0)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from importlib-metadata->transformers==4.6.0) (3.11.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from importlib-metadata->transformers==4.6.0) (4.4.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from packaging->transformers==4.6.0) (3.0.9)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from requests->transformers==4.6.0) (1.26.8)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from requests->transformers==4.6.0) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from requests->transformers==4.6.0) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from requests->transformers==4.6.0) (2022.12.7)
# Requirement already satisfied: joblib in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from sacremoses->transformers==4.6.0) (1.2.0)
# Requirement already satisfied: six in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from sacremoses->transformers==4.6.0) (1.16.0)
# Requirement already satisfied: click in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from sacremoses->transformers==4.6.0) (8.1.3)

# %% [markdown]
# ## Compile the model into an AWS Neuron optimized TorchScript

# %%
import torch
import torch_neuron

from transformers import AutoTokenizer, AutoModelForSequenceClassification, AutoConfig

# %%
# !pip install torch torch-scatter
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Requirement already satisfied: torch in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (1.13.1)
# Requirement already satisfied: torch-scatter in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (2.1.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from torch) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from torch) (11.7.99)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from torch) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from torch) (11.10.3.66)
# Requirement already satisfied: typing-extensions in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from torch) (4.4.0)
# Requirement already satisfied: wheel in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (0.38.4)
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (65.6.3)

# %%
from transformers import TapasTokenizer, TapasForQuestionAnswering
import pandas as pd
import torch


from transformers import AutoTokenizer, AutoModel

#tokenizer = AutoTokenizer.from_pretrained("google/tapas-base")
#model = AutoModel.from_pretrained("google/tapas-base")



# model_name = "google/tapas-base-finetuned-wtq"
# model_name = "google/tapas-small-finetuned-wtq"
model_name = "google/tapas-mini"
model = TapasForQuestionAnswering.from_pretrained(model_name)
tokenizer = TapasTokenizer.from_pretrained(model_name)
#tokenizer = AutoTokenizer.from_pretrained(model_name)

data = {"Actors": ["Brad Pitt", "Leonardo Di Caprio", "George Clooney"], "Number of movies": ["87", "53", "69"]}
queries = [
    "What is the name of the first actor?",
    "How many movies has George Clooney played in?",
    "What is the total number of movies?",
]
table = pd.DataFrame.from_dict(data)
inputs = tokenizer(table=table, queries=queries, padding="max_length", return_tensors="pt")
outputs = model(**inputs)
predicted_answer_coordinates, predicted_aggregation_indices = tokenizer.convert_logits_to_predictions(
    inputs, outputs.logits.detach(), outputs.logits_aggregation.detach()
)

"""
# let's print out the results:
id2aggregation = {0: "NONE", 1: "SUM", 2: "AVERAGE", 3: "COUNT"}
aggregation_predictions_string = [id2aggregation[x] for x in predicted_aggregation_indices]

answers = []
for coordinates in predicted_answer_coordinates:
    if len(coordinates) == 1:
        # only a single cell:
        answers.append(table.iat[coordinates[0]])
    else:
        # multiple cells
        cell_values = []
        for coordinate in coordinates:
            cell_values.append(table.iat[coordinate])
        answers.append(", ".join(cell_values))
"""




# Build tokenizer and model
# tokenizer = AutoTokenizer.from_pretrained("bert-base-cased-finetuned-mrpc")
# model = AutoModelForSequenceClassification.from_pretrained("bert-base-cased-finetuned-mrpc", return_dict=False)

# Setup some example inputs
sequence_0 = "The company HuggingFace is based in New York City"
sequence_1 = "Apples are especially bad for your health"
sequence_2 = "HuggingFace's headquarters are situated in Manhattan"

max_length=128
#paraphrase = tokenizer.encode_plus(sequence_0, sequence_2, max_length=max_length, padding='max_length', truncation=True, return_tensors="pt")
#not_paraphrase = tokenizer.encode_plus(sequence_0, sequence_1, max_length=max_length, padding='max_length', truncation=True, return_tensors="pt")

# Run the original PyTorch model on compilation exaple
#paraphrase_classification_logits = model(**paraphrase)[0]

# Convert example inputs to a format that is compatible with TorchScript tracing
#example_inputs_paraphrase = paraphrase['input_ids'], paraphrase['attention_mask'], paraphrase['token_type_ids']
#example_inputs_not_paraphrase = not_paraphrase['input_ids'], not_paraphrase['attention_mask'], not_paraphrase['token_type_ids']


example_inputs = inputs['input_ids'], inputs['attention_mask'], inputs['token_type_ids']
# Out:
# Downloading:   0%|          | 0.00/1.66k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/117M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/262k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/154 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/490 [00:00<?, ?B/s]

# %%
# Run torch.neuron.trace to generate a TorchScript that is optimized by AWS Neuron
# This step may need 3-5 min
# model_neuron = torch.neuron.trace(model, example_inputs_paraphrase, verbose=1, compiler_workdir='./compilation_artifacts')
# model_neuron = torch.neuron.trace(model, example_inputs, verbose=1, compiler_workdir='./compilation_artifacts')
model_neuron = torch.neuron.trace(model, example_inputs, verbose=1, compiler_workdir='./compilation_artifacts', strict=False)
# Out:
# /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/transformers/models/tapas/modeling_tapas.py:1511: TracerWarning: torch.as_tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   self.indices = torch.as_tensor(indices)
# /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/transformers/models/tapas/modeling_tapas.py:1512: TracerWarning: torch.as_tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   self.num_segments = torch.as_tensor(num_segments, device=indices.device)
# /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/transformers/models/tapas/modeling_tapas.py:1617: TracerWarning: torch.tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   batch_size = torch.prod(torch.tensor(list(index.batch_shape())))
# /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/transformers/models/tapas/modeling_tapas.py:1617: TracerWarning: Converting a tensor to a Python integer might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   batch_size = torch.prod(torch.tensor(list(index.batch_shape())))
# /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/transformers/models/tapas/modeling_tapas.py:1693: TracerWarning: torch.as_tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   [torch.as_tensor([-1], dtype=torch.long), torch.as_tensor(vector_shape, dtype=torch.long)], dim=0
# /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/transformers/models/tapas/modeling_tapas.py:1696: TracerWarning: Converting a tensor to a Python list might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   flat_values = values.reshape(flattened_shape.tolist())
# /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/transformers/models/tapas/modeling_tapas.py:1709: TracerWarning: torch.as_tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   torch.as_tensor(index.batch_shape(), dtype=torch.long),
# /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/transformers/models/tapas/modeling_tapas.py:1709: TracerWarning: Converting a tensor to a Python integer might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   torch.as_tensor(index.batch_shape(), dtype=torch.long),
# /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/transformers/models/tapas/modeling_tapas.py:1710: TracerWarning: torch.as_tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   torch.as_tensor([index.num_segments], dtype=torch.long),
# /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/transformers/models/tapas/modeling_tapas.py:1710: TracerWarning: Converting a tensor to a Python integer might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   torch.as_tensor([index.num_segments], dtype=torch.long),
# /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/transformers/models/tapas/modeling_tapas.py:1711: TracerWarning: torch.as_tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   torch.as_tensor(vector_shape, dtype=torch.long),
# /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/transformers/models/tapas/modeling_tapas.py:1716: TracerWarning: Converting a tensor to a Python list might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   output_values = segment_means.view(new_shape.tolist())
# /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/transformers/models/tapas/modeling_tapas.py:1645: TracerWarning: torch.as_tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   batch_shape, dtype=torch.long
# /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/transformers/models/tapas/modeling_tapas.py:1645: TracerWarning: Converting a tensor to a Python integer might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   batch_shape, dtype=torch.long
# /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/transformers/models/tapas/modeling_tapas.py:1648: TracerWarning: torch.as_tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   num_segments = torch.as_tensor(num_segments)  # create a rank 0 tensor (scalar) containing num_segments (e.g. 64)
# /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/transformers/models/tapas/modeling_tapas.py:1659: TracerWarning: Converting a tensor to a Python list might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   new_shape = [int(x) for x in new_tensor.tolist()]
# /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/transformers/models/tapas/modeling_tapas.py:1662: TracerWarning: torch.as_tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   multiples = torch.cat([batch_shape, torch.as_tensor([1])], dim=0)
# /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/transformers/models/tapas/modeling_tapas.py:1663: TracerWarning: Converting a tensor to a Python list might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   indices = indices.repeat(multiples.tolist())
# /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/transformers/models/tapas/modeling_tapas.py:309: TracerWarning: torch.as_tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   torch.as_tensor(self.config.max_position_embeddings - 1, device=device), position - first_position
# /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/transformers/modeling_utils.py:1968: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   input_tensor.shape[chunk_dim] == tensor_shape for input_tensor in input_tensors
# /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/transformers/models/tapas/modeling_tapas.py:1190: TracerWarning: torch.as_tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   indices=torch.min(row_ids, torch.as_tensor(self.config.max_num_rows - 1, device=row_ids.device)),
# /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/transformers/models/tapas/modeling_tapas.py:1195: TracerWarning: torch.as_tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   indices=torch.min(column_ids, torch.as_tensor(self.config.max_num_columns - 1, device=column_ids.device)),
# /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/transformers/models/tapas/modeling_tapas.py:1875: TracerWarning: torch.as_tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   is_padding, dtype=torch.float32, device=is_padding.device
# /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/transformers/models/tapas/modeling_tapas.py:1880: TracerWarning: torch.as_tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   torch.eq(out_index.indices, 0), dtype=torch.float32, device=out_index.indices.device
# /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/transformers/models/tapas/modeling_tapas.py:1915: TracerWarning: torch.as_tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   labels_per_column, _ = reduce_sum(torch.as_tensor(labels, dtype=torch.float32, device=labels.device), col_index)
# /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/transformers/models/tapas/modeling_tapas.py:1938: TracerWarning: torch.as_tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   torch.as_tensor(labels, dtype=torch.long, device=labels.device), cell_index
# /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/transformers/models/tapas/modeling_tapas.py:1948: TracerWarning: torch.as_tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   device=cell_mask.device,
# /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/transformers/models/tapas/modeling_tapas.py:1971: TracerWarning: torch.as_tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   torch.argmax(column_logits, dim=-1), dtype=torch.long, device=column_logits.device
# /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/transformers/models/tapas/modeling_tapas.py:1978: TracerWarning: torch.as_tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   device=selected_column_id.device,
# INFO:Neuron:There are 33 ops of 8 different types in the TorchScript that are not compiled by neuron-cc: aten::gather, aten::fmod, torch_scatter::scatter_max, aten::prod, aten::index_put_, aten::scatter_add_, aten::embedding, torch_scatter::scatter_min, (For more information see https://awsdocs-neuron.readthedocs-hosted.com/en/latest/release-notes/compiler/neuron-cc/neuron-cc-ops/neuron-cc-ops-pytorch.html)
# INFO:Neuron:Number of arithmetic operators (pre-compilation) before = 582, fused = 548, percent fused = 94.16%
# INFO:Neuron:Compiling function _NeuronGraph$293 with neuron-cc
# INFO:Neuron:Compiling with command line: '/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/bin/neuron-cc compile /home/ec2-user/SageMaker/scrub/aws-neuron-sdk/src/examples/pytorch/byoc_sm_bert_tutorial/compilation_artifacts/0/graph_def.pb --framework TENSORFLOW --pipeline compile SaveTemps --output /home/ec2-user/SageMaker/scrub/aws-neuron-sdk/src/examples/pytorch/byoc_sm_bert_tutorial/compilation_artifacts/0/graph_def.neff --io-config {"inputs": {"0:0": [[3, 512], "int64"]}, "outputs": ["TapasModel_7/TapasEmbeddings_27/aten_to_1/Const:0", "TapasModel_7/TapasEmbeddings_27/aten_reshape/Reshape:0"]} --verbose 1'
# 06/05/2023 06:07:36 AM INFO 15743 [root]: /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/bin/neuron-cc compile /home/ec2-user/SageMaker/scrub/aws-neuron-sdk/src/examples/pytorch/byoc_sm_bert_tutorial/compilation_artifacts/0/graph_def.pb --framework TENSORFLOW --pipeline compile SaveTemps --output /home/ec2-user/SageMaker/scrub/aws-neuron-sdk/src/examples/pytorch/byoc_sm_bert_tutorial/compilation_artifacts/0/graph_def.neff --io-config '{"inputs": {"0:0": [[3, 512], "int64"]}, "outputs": ["TapasModel_7/TapasEmbeddings_27/aten_to_1/Const:0", "TapasModel_7/TapasEmbeddings_27/aten_reshape/Reshape:0"]}' --verbose 1
# 06/05/2023 06:07:38 AM INFO 15743 [root]: Intermediate files stored in /home/ec2-user/SageMaker/scrub/aws-neuron-sdk/src/examples/pytorch/byoc_sm_bert_tutorial/compilation_artifacts/0, output in /home/ec2-user/SageMaker/scrub/aws-neuron-sdk/src/examples/pytorch/byoc_sm_bert_tutorial/compilation_artifacts/0
# 06/05/2023 06:07:38 AM INFO 15743 [pipeline.custom.0]: Running pipeline custom.0
# 06/05/2023 06:07:38 AM INFO 15743 [pipeline.custom.0]: Starting job pipeline.compile.0 state state 0
# 06/05/2023 06:07:38 AM INFO 15743 [pipeline.compile.0]: Running pipeline compile.0
# 06/05/2023 06:07:38 AM INFO 15743 [pipeline.compile.0]: Starting job job.Frontend.4 state state 0
# 06/05/2023 06:07:38 AM INFO 15743 [job.Frontend.4]: Replay this job by calling: /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/bin/neuron-cc compile --framework TENSORFLOW --state '{"model": ["/home/ec2-user/SageMaker/scrub/aws-neuron-sdk/src/examples/pytorch/byoc_sm_bert_tutorial/compilation_artifacts/0/graph_def.pb"], "state_dir": "/home/ec2-user/SageMaker/scrub/aws-neuron-sdk/src/examples/pytorch/byoc_sm_bert_tutorial/compilation_artifacts/0", "state_id": "root"}' --pipeline Frontend --io-config '{"inputs": {"0:0": [[3, 512], "int64"]}, "outputs": ["TapasModel_7/TapasEmbeddings_27/aten_to_1/Const:0", "TapasModel_7/TapasEmbeddings_27/aten_reshape/Reshape:0"]}' --framework TENSORFLOW
# 06/05/2023 06:07:40 AM INFO 15743 [job.Frontend.4]: IR signature: 5b1bcb9e84ba505b56729798438f64845f49a2e5a03d1758a974f2052aa58d3c for graph_def.pb
# 06/05/2023 06:07:40 AM INFO 15743 [job.Frontend.4]: total padded opcount is 0
# 06/05/2023 06:07:40 AM INFO 15743 [job.Frontend.4]: Finished Jellyfish import
# 06/05/2023 06:07:40 AM INFO 15743 [job.Frontend.4]: Start tensorization
# [06:07:40] /opt/brazil-pkg-cache/packages/DmlcTvm/DmlcTvm-1.15.0.0/AL2_x86_64/generic-flavor/src/src/relay/pass/coloring/cgraph_painter.cc:82:
# Coloring: number graph parts=1
# Coloring: number sbuf rows=128
# Coloring: number sbuf bytes=76800
# Coloring: static weights=0
#
# [06:07:40] /opt/brazil-pkg-cache/packages/DmlcTvm/DmlcTvm-1.15.0.0/AL2_x86_64/generic-flavor/src/src/relay/pass/coloring/cgraph_painter.cc:192:
# Coloring: Total cycles=0
# Coloring: Total const bytes per part=97
# Coloring: Byte threshold = 72960
#
# [06:07:40] /opt/brazil-pkg-cache/packages/DmlcTvm/DmlcTvm-1.15.0.0/AL2_x86_64/generic-flavor/src/src/relay/pass/coloring/cgraph_stats.cc:157:
#
# Coloring: Total number of cycles: 0. Average number of cycles per partition: 0
#  Color         #Clocks   Weights    MaxIfmap   #Conv2D    #Dense   #OtherOps
#      0               0        97           0         0         0           2
# Coloring: Total nubmer of cycles = 0
# Coloring: Largest number of cycles in part = 0, Ratio worst/best avg = -nan
#
#
#
# [06:07:40] /opt/brazil-pkg-cache/packages/DmlcTvm/DmlcTvm-1.15.0.0/AL2_x86_64/generic-flavor/src/src/relay/pass/coloring/cgraph_painter.cc:757:
#            Color  Hash
#      tonga0:tpb0  TapasModel_7/TapasEmbeddings_27/aten_reshape/Reshape:0
#      tonga0:tpb0  TapasModel_7/TapasEmbeddings_27/aten_to_1/Const:0
#
#            Color  Target
#      tonga0:tpb0  tonga
#         cpu0:cpu  llvm -mcpu=skylake-avx512
#      cpu1000:cpu  llvm
#
#
# 06/05/2023 06:07:40 AM INFO 15743 [job.Frontend.4]: IR signature: b8a099c110d2dd3ad7d2577fc5efdc265d491e25c54966648f1e34828f32c073 for relay_graph_post_opt_unit_level.txt
# 06/05/2023 06:07:40 AM INFO 15743 [root/Tensorizer/All]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [Tensorizer]: Tensorizer options:  --fp32-cast=all  --disable-bitcasted-transpose  --disable-expensive-checks  --disable-max-stride-tiling  --enable-replication  --max-local-tensor-tile-size-in-bytes=16384  --tensor-layout-p-order=0  --tensor-layout-b-order=1  --enable-advanced-delinearization  --weight-coalescing-threshold=512  --disable-shifted-fusion  --enable-bir-converter=enable
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/RelayPasses]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/RelayPasses]: Exit time region: delta=0.027s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/IRBuilder]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/IRBuilder]: Exit time region: delta=0.008s
# 06/05/2023 06:07:40 AM INFO 15743 [Tensorizer]: Tensorizer options:  --fp32-cast=all  --disable-bitcasted-transpose  --disable-expensive-checks  --disable-max-stride-tiling  --enable-replication  --max-local-tensor-tile-size-in-bytes=16384  --tensor-layout-p-order=0  --tensor-layout-b-order=1  --enable-advanced-delinearization  --weight-coalescing-threshold=512  --disable-shifted-fusion  --enable-bir-converter=enable
# 06/05/2023 06:07:40 AM INFO 15743 [Tensorizer]: Generate: 1 statements from relay. Start optimizations ...
# 06/05/2023 06:07:40 AM INFO 15743 [Statistics]: Weights total number of bytes: 12296
# 06/05/2023 06:07:40 AM INFO 15743 [Statistics]: RelayIF total number of bytes: 0.0
# 06/05/2023 06:07:40 AM INFO 15743 [Statistics]: RelayOF total number of bytes: 12296.0
# 06/05/2023 06:07:40 AM INFO 15743 [Statistics]: Weights total number of bytes: 12296.0
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/DoNothing]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [DoNothing]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/DoNothing]: Exit time region: delta=0.001s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/MutateDataType]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [MutateDataType]: Finished (changed=True #instances=6148)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/MutateDataType]: Exit time region: delta=0.003s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/ResolveEqualPredicates]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [ResolveEqualPredicates]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/ResolveEqualPredicates]: Exit time region: delta=0.001s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/EliminateDivs]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [EliminateDivs]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/EliminateDivs]: Exit time region: delta=0.001s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/SimplifyPredicates]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [SimplifyPredicates]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/SimplifyPredicates]: Exit time region: delta=0.008s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/Simplifier]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [Simplifier]: Finished (changed=True #instances=6146)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/Simplifier]: Exit time region: delta=0.002s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/TCTransform]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [TCTransform]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/TCTransform]: Exit time region: delta=0.001s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/CommuteConcat]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [CommuteConcat]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/CommuteConcat]: Exit time region: delta=0.001s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/LoopFusion]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [LoopFusion]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/LoopFusion]: Exit time region: delta=0.002s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/Simplifier]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [Simplifier]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/Simplifier]: Exit time region: delta=0.001s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/DelinearIndices]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [DelinearIndices]: Finished (changed=True #instances=6146)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/DelinearIndices]: Exit time region: delta=0.001s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/Delinearization]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [Delinearization]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/Delinearization]: Exit time region: delta=0.001s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/DeadStoreElimination]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [DeadStoreElimination]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/DeadStoreElimination]: Exit time region: delta=0.012s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/Simplifier]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [Simplifier]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/Simplifier]: Exit time region: delta=0.001s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/LICM]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [LICM]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/LICM]: Exit time region: delta=0.001s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/DelinearIndices]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [DelinearIndices]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/DelinearIndices]: Exit time region: delta=0.001s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/Delinearization]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [Delinearization]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/Delinearization]: Exit time region: delta=0.001s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/LoopFusion]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [LoopFusion]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/LoopFusion]: Exit time region: delta=0.001s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/LICM]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [LICM]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/LICM]: Exit time region: delta=0.001s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/Simplifier]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [Simplifier]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/Simplifier]: Exit time region: delta=0.001s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/ValueNumbering]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [ValueNumbering]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/ValueNumbering]: Exit time region: delta=0.001s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/LICM]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [LICM]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/LICM]: Exit time region: delta=0.001s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/MemcpyElimination]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [MemcpyElimination]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/MemcpyElimination]: Exit time region: delta=0.001s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/PadElimination]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [PadElimination]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/PadElimination]: Exit time region: delta=0.001s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/DelinearIndices]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [DelinearIndices]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/DelinearIndices]: Exit time region: delta=0.001s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/Delinearization]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [Delinearization]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/Delinearization]: Exit time region: delta=0.001s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/LoopFusion]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [LoopFusion]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/LoopFusion]: Exit time region: delta=0.001s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/Simplifier]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [Simplifier]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/Simplifier]: Exit time region: delta=0.001s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/LICM]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [LICM]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/LICM]: Exit time region: delta=0.001s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/ValueNumbering]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [ValueNumbering]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/ValueNumbering]: Exit time region: delta=0.001s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/TCTransform]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [TCTransform]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/TCTransform]: Exit time region: delta=0.001s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/CommuteConcat]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [CommuteConcat]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/CommuteConcat]: Exit time region: delta=0.001s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/LoopFusion]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [LoopFusion]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/LoopFusion]: Exit time region: delta=0.001s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/ValueNumbering]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [ValueNumbering]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/ValueNumbering]: Exit time region: delta=0.001s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/RecognizeOpIdiom]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [RecognizeOpIdiom]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/RecognizeOpIdiom]: Exit time region: delta=0.001s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/DeadCodeElimination]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [DeadCodeElimination]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/DeadCodeElimination]: Exit time region: delta=0.001s
# 06/05/2023 06:07:40 AM INFO 15743 [Tensorizer]: After optimization: 1 statements
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/AutoCastFP32]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [AutoCastFP32]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/AutoCastFP32]: Exit time region: delta=0.001s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/LoopFusion]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [LoopFusion]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/LoopFusion]: Exit time region: delta=0.001s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/Simplifier]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [Simplifier]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/Simplifier]: Exit time region: delta=0.001s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/Delinearization]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [Delinearization]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/Delinearization]: Exit time region: delta=0.001s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/ResolveAccessConflict]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [ResolveAccessConflict]: Finished (changed=True #instances=12294)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/ResolveAccessConflict]: Exit time region: delta=0.002s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/TransformLayout]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [TransformLayout]: Finished (changed=True #instances=12294)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/TransformLayout]: Exit time region: delta=0.006s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/PartitionLocalityOpt]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [PartitionLocalityOpt]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/PartitionLocalityOpt]: Exit time region: delta=0.002s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/FlattenPartitionAxes]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [FlattenPartitionAxes]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/FlattenPartitionAxes]: Exit time region: delta=0.001s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/TongaSizeTiling]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [TongaSizeTiling]: Finished (changed=True #instances=40)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/TongaSizeTiling]: Exit time region: delta=0.013s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/TilingProfiler]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [TilingProfiler]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/TilingProfiler]: Exit time region: delta=0.001s
# 06/05/2023 06:07:40 AM INFO 15743 [Tensorizer]: Default layout and tiling instruction count within range.
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/FlattenMacroLoop]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [FlattenMacroLoop]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/FlattenMacroLoop]: Exit time region: delta=0.001s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/RetileSIMDMacro]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [RetileSIMDMacro]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/RetileSIMDMacro]: Exit time region: delta=0.001s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/InferTongaTensor]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [InferTongaTensor]: Finished (changed=True #instances=40)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/InferTongaTensor]: Exit time region: delta=0.003s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/TongaSimplifier]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [TongaSimplifier]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/TongaSimplifier]: Exit time region: delta=0.001s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/LICM]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [LICM]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/LICM]: Exit time region: delta=0.001s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/RewriteReplicationMatmul]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [RewriteReplicationMatmul]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/RewriteReplicationMatmul]: Exit time region: delta=0.001s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/FlattenMacroLoop]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [FlattenMacroLoop]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/FlattenMacroLoop]: Exit time region: delta=0.001s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/SimplifyPredicates]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [SimplifyPredicates]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/SimplifyPredicates]: Exit time region: delta=0.002s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/DataLocalityOpt]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [DataLocalityOpt]: Finished (changed=True #instances=54)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/DataLocalityOpt]: Exit time region: delta=0.026s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/TongaSimplifier]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [TongaSimplifier]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/TongaSimplifier]: Exit time region: delta=0.002s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/LegalizeTongaMacro]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [LegalizeTongaMacro]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/LegalizeTongaMacro]: Exit time region: delta=0.002s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/TongaSimplifier]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [TongaSimplifier]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/TongaSimplifier]: Exit time region: delta=0.002s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/PerfectLoopNest]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [PerfectLoopNest]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/PerfectLoopNest]: Exit time region: delta=0.002s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/FlattenMacroLoop]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [FlattenMacroLoop]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/FlattenMacroLoop]: Exit time region: delta=0.002s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/RewriteWeights]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [RewriteWeights]: Finished (changed=True #instances=54)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/RewriteWeights]: Exit time region: delta=0.004s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/ReshapeWeights]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [ReshapeWeights]: Finished (changed=True #instances=54)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/ReshapeWeights]: Exit time region: delta=0.002s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/FlattenMacroLoop]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [FlattenMacroLoop]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/FlattenMacroLoop]: Exit time region: delta=0.002s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/SimplifyPredicates]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [SimplifyPredicates]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/SimplifyPredicates]: Exit time region: delta=0.004s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/InferInitValue]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [InferInitValue]: Finished (changed=True #instances=54)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/InferInitValue]: Exit time region: delta=0.014s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/SplitUnionSets]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [SplitUnionSets]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/SplitUnionSets]: Exit time region: delta=0.002s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/TongaSimplifier]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [TongaSimplifier]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/TongaSimplifier]: Exit time region: delta=0.002s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/SimplifyTongaTensor]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [SimplifyTongaTensor]: Finished (changed=True #instances=54)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/SimplifyTongaTensor]: Exit time region: delta=0.004s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/LegalizeTongaStore]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [LegalizeTongaStore]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/LegalizeTongaStore]: Exit time region: delta=0.002s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/LICM]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [LICM]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/LICM]: Exit time region: delta=0.002s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/TongaISel]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [TongaISel]: Finished (changed=True #instances=78)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/TongaISel]: Exit time region: delta=0.012s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/TongaAffineLoopXform]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [TongaAffineLoopXform]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/TongaAffineLoopXform]: Exit time region: delta=0.002s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/TongaLoopFusion]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [TongaLoopFusion]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/TongaLoopFusion]: Exit time region: delta=0.004s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/TongaLICM]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [TongaLICM]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/TongaLICM]: Exit time region: delta=0.002s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/FactorizeBlkDims]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [FactorizeBlkDims]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/FactorizeBlkDims]: Exit time region: delta=0.003s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/TongaInstComb]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [TongaInstComb]: Finished (changed=True #instances=66)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/TongaInstComb]: Exit time region: delta=0.014s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/TongaValueNumbering]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [TongaValueNumbering]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/TongaValueNumbering]: Exit time region: delta=0.003s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/LowerTranspose]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [LowerTranspose]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/LowerTranspose]: Exit time region: delta=0.002s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/LegalizeTongaType]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [LegalizeTongaType]: Finished (changed=True #instances=66)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/LegalizeTongaType]: Exit time region: delta=0.002s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/PartialLoopFusion]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [PartialLoopFusion]: Finished (changed=True #instances=66)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/PartialLoopFusion]: Exit time region: delta=0.014s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/ShortenLifeInterval]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [ShortenLifeInterval]: Finished (changed=True #instances=66)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/ShortenLifeInterval]: Exit time region: delta=0.003s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/GlobalBatchOpt]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [GlobalBatchOpt]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/GlobalBatchOpt]: Exit time region: delta=0.002s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/SpillPSum]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [SpillPSum]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/SpillPSum]: Exit time region: delta=0.003s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/LegalizeTongaType]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [LegalizeTongaType]: Finished (changed=True #instances=66)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/LegalizeTongaType]: Exit time region: delta=0.002s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/InferPSumTensor]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [InferPSumTensor]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/InferPSumTensor]: Exit time region: delta=0.002s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/VectorizeMatMult]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [VectorizeMatMult]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/VectorizeMatMult]: Exit time region: delta=0.002s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/WeightCoalescing]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [WeightCoalescing]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/WeightCoalescing]: Exit time region: delta=0.002s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/LowerPartitionTile]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [LowerPartitionTile]: Finished (changed=True #instances=114)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/LowerPartitionTile]: Exit time region: delta=0.004s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/BroadcastWeights]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [BroadcastWeights]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/BroadcastWeights]: Exit time region: delta=0.002s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/TensorInitialization]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [TensorInitialization]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/TensorInitialization]: Exit time region: delta=0.002s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/LegalizeTongaAccess]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [LegalizeTongaAccess]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/LegalizeTongaAccess]: Exit time region: delta=0.003s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/TongaAffineLoopXform]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [TongaAffineLoopXform]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/TongaAffineLoopXform]: Exit time region: delta=0.002s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/RelaxPredicates]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [RelaxPredicates]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/RelaxPredicates]: Exit time region: delta=0.002s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/TensorInitialization]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [TensorInitialization]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/TensorInitialization]: Exit time region: delta=0.002s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/ExpandISAMacro]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [ExpandISAMacro]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/ExpandISAMacro]: Exit time region: delta=0.002s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/LegalizePartitionTile]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [LegalizePartitionTile]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/LegalizePartitionTile]: Exit time region: delta=0.002s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/SimplifyTongaTensor]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [SimplifyTongaTensor]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/SimplifyTongaTensor]: Exit time region: delta=0.004s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/LinearizeFreeDim]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [LinearizeFreeDim]: Finished (changed=True #instances=114)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/LinearizeFreeDim]: Exit time region: delta=0.002s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/DataStreaming]: Enter time region
# 06/05/2023 06:07:40 AM INFO 15743 [DataStreaming]: Finished (changed=False)
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/DataStreaming]: Exit time region: delta=0.002s
# 06/05/2023 06:07:40 AM INFO 15743 [sg00/Tensorizer/ILPOpt]: Enter time region
# ...
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]:               safe = 13
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]:             unsafe = 0
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]:                inf = 0
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]:       preallocated = 0
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]:              total = 13
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]:           simplify
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]:             new candidates = 0
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]:         select ranges
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]:           success
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]:         SB score = 0
# 06/05/2023 06:09:46 AM WARNING [WalrusDriver.0]: spilling from SB cost about 0 cycles
# 06/05/2023 06:09:46 AM WARNING [WalrusDriver.0]: 296 bytes/partition (100%) successfully pinned
# 06/05/2023 06:09:46 AM WARNING [WalrusDriver.0]: pinning saved approximately 5691 cycles
# 06/05/2023 06:09:46 AM WARNING [WalrusDriver.0]: 1% SB utilization after allocation
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: ru_maxrss:  2756mb (delta=0mb)
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: Walrus pass: coloring_allocator succeeded!
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: Output has 1 module(s), 1 function(s), 26 memory location(s), 1 block(s), and 42 instruction(s).
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: Running walrus pass: dma_optimization
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: Input to dma_optimization: modules=1 functions=1 allocs=26 blocks=1 instructions=42
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: PSUM Rotation rotated 5 PSUM Banks, reduced 1 consecutive Matmul Accumulation group dst PSUM Allocation
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: PSUM Rotation rotated 0 PSUM Banks, reduced 0 consecutive Activation source PSUM Allocation
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: PSUM Rotation rotated 0 PSUM Banks, reduced 0 consecutive DVE engine source/dst PSUM Allocation
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: DMA optimization In bytes loaded or saved 55392, 88.8215% input load, 11.1785% output write, 0% spill/reload
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: [Load Merging]: removed 0 GCA remat/cloned instructions
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: [Load Merging] reduced input/const loading DMA traffic 0, 0% out of total input/const loading dma traffic
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: [spill optimization round 0]: removed 0 spill/reload instructions
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: [spill optimization round 0]: removed 0 spill/reload memory locations
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: [Spill Optimization] reduced DMA traffic 0, -nan% out of total spill/reload dma traffic
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: [Allocation optimization]: removed 0 spill/reload instructions
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: [Allocation optimization]: removed 0 spill/reload memory locations
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: [Re-allocation Optimization] reduced DMA traffic 0, -nan% out of total spill/reload dma traffic
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: [spill optimization round 0]: removed 0 spill/reload instructions
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: [spill optimization round 0]: removed 0 spill/reload memory locations
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: [Spill Optimization] reduced DMA traffic 0, -nan% out of total spill/reload dma traffic
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: [DMA optimization] reduced DMA traffic 0, 0% out of total dma traffic
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: DMA optimization Out bytes loaded or saved 55392, 88.8215% input load, 11.1785% output write, 0% spill/reload
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: INFO: Post DMA optimization DRAM bytes loaded 49200
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: INFO: Post DMA optimization average loaded DMA size 182 bytes
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: INFO: Post DMA optimization DRAM bytes saved 6192
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: INFO: Post DMA optimization average saved DMA size 1032 bytes
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: INFO: Post DMA optimization DRAM bytes DMAcopyed 0
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: INFO: Post DMA optimization average DMAcopyed DMA size 0 bytes
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: [Experiment partial DMA access] reduced DMA traffic 0, -nan% out of total spill/reload dma traffic
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: DMA SpillSave Coalescing Round 0 combined 0 SpillSaves and Reloads
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: INFO: Post DMA coalescing DRAM bytes loaded 49200
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: INFO: Post DMA coalescing average loaded DMA size 182 bytes
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: INFO: Post DMA coalescing DRAM bytes saved 6192
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: INFO: Post DMA coalescing average saved DMA size 1032 bytes
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: SB Rotation rotated 0 Sb address, reduced 0 consecutive SpillSave overlapping address
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: SB Rotation rotated 0 Sb address, reduced 0 consecutive Load overlapping address
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: SB Rotation rotated 0 Sb address, reduced 0 consecutive Any overlapping address
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: Reload number 0
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: Spill number 0
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: DMA optimization enable optimization
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: ru_maxrss:  2756mb (delta=0mb)
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: Walrus pass: dma_optimization succeeded!
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: Output has 1 module(s), 1 function(s), 26 memory location(s), 1 block(s), and 42 instruction(s).
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: Running walrus pass: build_fdeps
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: Input to build_fdeps: modules=1 functions=1 allocs=26 blocks=1 instructions=42
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: ru_maxrss:  2756mb (delta=0mb)
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: Walrus pass: build_fdeps succeeded!
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: Output has 1 module(s), 1 function(s), 26 memory location(s), 1 block(s), and 42 instruction(s).
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: Running walrus pass: remove_redundancies
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: Input to remove_redundancies: modules=1 functions=1 allocs=26 blocks=1 instructions=42
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: ru_maxrss:  2756mb (delta=0mb)
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: Walrus pass: remove_redundancies succeeded!
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: Output has 1 module(s), 1 function(s), 26 memory location(s), 1 block(s), and 42 instruction(s).
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: Running walrus pass: anti_dependency_analyzer
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: Input to anti_dependency_analyzer: modules=1 functions=1 allocs=26 blocks=1 instructions=42
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: ru_maxrss:  2756mb (delta=0mb)
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: Walrus pass: anti_dependency_analyzer succeeded!
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: Output has 1 module(s), 1 function(s), 26 memory location(s), 1 block(s), and 42 instruction(s).
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: Running walrus pass: post_sched
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: Input to post_sched: modules=1 functions=1 allocs=26 blocks=1 instructions=42
# 06/05/2023 06:09:46 AM INFO [TheScheduler.0]: Start PosT ScheD 2 inferentia Mon Jun  5 06:09:46 2023
# 06/05/2023 06:09:46 AM INFO [TheScheduler.0]: Done  PosT ScheD Mon Jun  5 06:09:46 2023
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: ru_maxrss:  2756mb (delta=0mb)
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: Walrus pass: post_sched succeeded!
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: Output has 1 module(s), 1 function(s), 26 memory location(s), 1 block(s), and 42 instruction(s).
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: Running walrus pass: tensorcopy_accel
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: Input to tensorcopy_accel: modules=1 functions=1 allocs=26 blocks=1 instructions=42
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: Running peephole optimization pass
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: ru_maxrss:  2756mb (delta=0mb)
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: Walrus pass: tensorcopy_accel succeeded!
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: Output has 1 module(s), 1 function(s), 26 memory location(s), 1 block(s), and 42 instruction(s).
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: Running walrus pass: birverifier
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: Input to birverifier: modules=1 functions=1 allocs=26 blocks=1 instructions=42
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: ru_maxrss:  2756mb (delta=0mb)
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: Walrus pass: birverifier succeeded!
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: Output has 1 module(s), 1 function(s), 26 memory location(s), 1 block(s), and 42 instruction(s).
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: Running walrus pass: run_stargazer
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: Input to run_stargazer: modules=1 functions=1 allocs=26 blocks=1 instructions=42
# 06/05/2023 06:09:46 AM INFO [Stargazer.0]: Stargazer starts [in memory BIR module]
# 06/05/2023 06:09:46 AM INFO [Stargazer.0]: Current working directory: "/home/ec2-user/SageMaker/scrub/aws-neuron-sdk/src/examples/pytorch/byoc_sm_bert_tutorial/compilation_artifacts/133/sg00"
# 06/05/2023 06:09:46 AM INFO [Stargazer.0]: Generating Arch 'Inferentia-1.0'
# 06/05/2023 06:09:46 AM INFO [Stargazer.0]: INFO: Pre SG DRAM bytes loaded or saved 55392
# 06/05/2023 06:09:46 AM INFO [Stargazer.0]: INFO: Pre SG average DMA size 200 bytes
# 06/05/2023 06:09:46 AM INFO [Stargazer.0]: Num Loads in Func = 6
# 06/05/2023 06:09:46 AM INFO [Stargazer.0]: Num Saves in Func = 2
# 06/05/2023 06:09:46 AM INFO [Stargazer.0]: Num Input Loads in Func= 6
# 06/05/2023 06:09:46 AM INFO [Stargazer.0]: Num Output Saves in Func= 2
# 06/05/2023 06:09:46 AM INFO [Stargazer.0]: Num Spill Loads in Func= 0
# 06/05/2023 06:09:46 AM INFO [Stargazer.0]: Num Spill Saves in Func= 0
# 06/05/2023 06:09:46 AM INFO [Stargazer.0]: Wavegraph code generation for Inferentia:
# 06/05/2023 06:09:46 AM INFO [Stargazer.0]:     Engine              File
# 06/05/2023 06:09:46 AM INFO [Stargazer.0]:     ------              ----
# 06/05/2023 06:09:46 AM INFO [Stargazer.0]:     PE-Array            pe.bin
# 06/05/2023 06:09:46 AM INFO [Stargazer.0]:     Pool-Eng            pool.bin
# 06/05/2023 06:09:46 AM INFO [Stargazer.0]:     Act-Eng             act.bin
# 06/05/2023 06:09:46 AM INFO [Stargazer.0]:
# 06/05/2023 06:09:46 AM INFO [Stargazer.0]: Fixing data race is 0
# 06/05/2023 06:09:46 AM INFO [Stargazer.0]: Data race checker engines
# 06/05/2023 06:09:46 AM INFO [Stargazer.0]: [Sailfish] Data race analysis initially
# 06/05/2023 06:09:46 AM INFO [Stargazer.0]: [Sailfish] Data race analysis found no races, run time: 0:00:00
# 06/05/2023 06:09:46 AM INFO [Stargazer.0]: [Sailfish] Remove redundant edges
# 06/05/2023 06:09:46 AM INFO [Stargazer.0]: Data race checker engines
# 06/05/2023 06:09:46 AM INFO [Stargazer.0]: Transitive reduction start
# 06/05/2023 06:09:46 AM INFO [Stargazer.0]: Transitive reduction removed 0 redundant edges, time: 0:00:00
# 06/05/2023 06:09:46 AM INFO [Stargazer.0]: Sync Critical Load Chains Start
# 06/05/2023 06:09:46 AM INFO [Stargazer.0]: Sync Critical Load Chains added 0 new Load-2-Load syncs
# 06/05/2023 06:09:46 AM INFO [Stargazer.0]: Sync Critical Load Chains Done.0:00:00
# 06/05/2023 06:09:46 AM INFO [Stargazer.0]: Out wavegraph bin file is wavegraph-bin.json
# 06/05/2023 06:09:46 AM INFO [Stargazer.0]: Writing NN JSON to file 'wavegraph-bin.json'
# 06/05/2023 06:09:46 AM INFO [Stargazer.0]: Virtual memory peak = 1652964 K bytes
# 06/05/2023 06:09:46 AM INFO [Stargazer.0]: PASSED - Total time: 0:00:00
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: ru_maxrss:  2756mb (delta=0mb)
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: Walrus pass: run_stargazer succeeded!
# 06/05/2023 06:09:46 AM INFO [WalrusDriver.0]: Output has 1 module(s), 1 function(s), 26 memory location(s), 1 block(s), and 42 instruction(s).
# INFO:Neuron:Number of arithmetic operators (post-compilation) before = 582, compiled = 86, percent compiled = 14.78%
# INFO:Neuron:The neuron partitioner created 25 sub-graphs
# INFO:Neuron:Neuron successfully compiled 15 sub-graphs, Total fused subgraphs = 25, Percent of model sub-graphs successfully compiled = 60.0%
# INFO:Neuron:Compiled these operators (and operator counts) to Neuron:
# INFO:Neuron: => aten::Int: 11
# INFO:Neuron: => aten::ScalarImplicit: 3
# INFO:Neuron: => aten::add: 2
# INFO:Neuron: => aten::arange: 3
# INFO:Neuron: => aten::expand: 1
# INFO:Neuron: => aten::linear: 1
# INFO:Neuron: => aten::min: 1
# INFO:Neuron: => aten::mul: 3
# INFO:Neuron: => aten::reshape: 1
# INFO:Neuron: => aten::select: 9
# INFO:Neuron: => aten::size: 11
# INFO:Neuron: => aten::slice: 18
# INFO:Neuron: => aten::sub: 1
# INFO:Neuron: => aten::to: 9
# INFO:Neuron: => aten::unsqueeze: 3
# INFO:Neuron: => aten::view: 6
# INFO:Neuron: => aten::zeros: 3
# INFO:Neuron:Not compiled operators (and operator counts) to Neuron:
# INFO:Neuron: => aten::Int: 60 [supported]
# INFO:Neuron: => aten::ScalarImplicit: 9 [supported]
# INFO:Neuron: => aten::add: 24 [supported]
# INFO:Neuron: => aten::add_: 9 [supported]
# INFO:Neuron: => aten::arange: 9 [supported]
# INFO:Neuron: => aten::argmax: 1 [supported]
# INFO:Neuron: => aten::bitwise_not: 1 [supported]
# INFO:Neuron: => aten::broadcast_tensors: 2 [supported]
# INFO:Neuron: => aten::contiguous: 4 [supported]
# INFO:Neuron: => aten::detach: 7 [supported]
# INFO:Neuron: => aten::div: 5 [supported]
# INFO:Neuron: => aten::div_: 4 [supported]
# INFO:Neuron: => aten::dropout: 14 [supported]
# INFO:Neuron: => aten::einsum: 2 [supported]
# INFO:Neuron: => aten::embedding: 9 [not supported]
# INFO:Neuron: => aten::eq: 4 [supported]
# INFO:Neuron: => aten::expand: 11 [supported]
# INFO:Neuron: => aten::floor: 2 [supported]
# INFO:Neuron: => aten::fmod: 2 [not supported]
# INFO:Neuron: => aten::gather: 2 [not supported]
# INFO:Neuron: => aten::gelu: 4 [supported]
# INFO:Neuron: => aten::index_put_: 3 [not supported]
# INFO:Neuron: => aten::layer_norm: 9 [supported]
# INFO:Neuron: => aten::linear: 25 [supported]
# INFO:Neuron: => aten::logical_and: 1 [supported]
# INFO:Neuron: => aten::lt: 4 [supported]
# INFO:Neuron: => aten::matmul: 8 [supported]
# INFO:Neuron: => aten::min: 2 [supported]
# INFO:Neuron: => aten::mul: 19 [supported]
# INFO:Neuron: => aten::ones: 3 [supported]
# INFO:Neuron: => aten::permute: 16 [supported]
# INFO:Neuron: => aten::prod: 7 [not supported]
# INFO:Neuron: => aten::repeat: 3 [supported]
# INFO:Neuron: => aten::reshape: 6 [supported]
# INFO:Neuron: => aten::rsub: 2 [supported]
# INFO:Neuron: => aten::scatter_add_: 8 [not supported]
# INFO:Neuron: => aten::select: 3 [supported]
# INFO:Neuron: => aten::size: 55 [supported]
# INFO:Neuron: => aten::slice: 7 [supported]
# INFO:Neuron: => aten::softmax: 4 [supported]
# INFO:Neuron: => aten::tanh: 1 [supported]
# INFO:Neuron: => aten::to: 65 [supported]
# INFO:Neuron: => aten::transpose: 4 [supported]
# INFO:Neuron: => aten::unsqueeze: 9 [supported]
# INFO:Neuron: => aten::view: 39 [supported]
# INFO:Neuron: => aten::where: 1 [not supported]
# INFO:Neuron: => aten::zeros: 5 [supported]
# INFO:Neuron: => aten::zeros_like: 2 [supported]
# WARNING:Neuron:torch.neuron.trace was unable to compile > 50% of the operators in the compiled model!
# WARNING:Neuron:Please review the torch.neuron.analyze_model output and if you believe you are seeing a failure
# WARNING:Neuron:Lodge an issue on https://github.com/aws/aws-neuron-sdk/issues if you believe the model is not compiling as expected

# %% [markdown]
# You may inspect **model_neuron.graph** to see which part is running on CPU versus running on the accelerator. All native **aten** operators in the graph will be running on CPU.

# %%
# See  which part is running on CPU versus running on the accelerator.
print(model_neuron.graph)

# %% [markdown]
# Save the compiled model, so it can be packaged and sent to S3.

# %%
# Save the TorchScript for later use
model_neuron.save('neuron_compiled_model.pt')

# %% [markdown]
# ### Package the pre-trained model and upload it to S3
#
# To make the model available for the SageMaker deployment, you will TAR the serialized graph and upload it to the default Amazon S3 bucket for your SageMaker session.

# %%
# Now you'll create a model.tar.gz file to be used by SageMaker endpoint
# !tar -czvf model.tar.gz neuron_compiled_model.pt

# %%
import boto3
import time
from sagemaker.utils import name_from_base
import sagemaker

# %%
# upload model to S3
role = sagemaker.get_execution_role()
sess=sagemaker.Session()
region=sess.boto_region_name
bucket=sess.default_bucket()
sm_client=boto3.client('sagemaker')

# %%
model_key = '{}/model/model.tar.gz'.format('inf1_compiled_model')
model_path = 's3://{}/{}'.format(bucket, model_key)
boto3.resource('s3').Bucket(bucket).upload_file('model.tar.gz', model_key)
print("Uploaded model to S3:")
print(model_path)

# %% [markdown]
# ## Build and Push the container

# %% [markdown]
# The following shell code shows how to build the container image using docker build and push the container image to ECR using docker push.
# The Dockerfile in this example is available in the ***container*** folder.
# Here's an example of the Dockerfile:
#
# ```Dockerfile
# FROM 763104351884.dkr.ecr.us-east-1.amazonaws.com/pytorch-inference-neuron:1.7.1-neuron-py36-ubuntu18.04
#
# # Install packages
# RUN pip install "transformers==4.7.0"
# ```

# %%
# !cat container/Dockerfile

# %% [markdown]
# Before running the next cell, make sure your SageMaker IAM role has access to ECR. If not, you can attache the role `AmazonEC2ContainerRegistryPowerUser` to your IAM role ARN, which allows you to upload image layers to ECR.
#
# It takes 5 minutes to build docker images and upload image to ECR

# %%
# %%sh
#
# # The name of our algorithm
# algorithm_name=neuron-py36-inference
#
# cd container
#
# account=$(aws sts get-caller-identity --query Account --output text)
#
# # Get the region defined in the current configuration (default to us-west-2 if none defined)
# region=$(aws configure get region)
# region=${region:-us-west-2}
#
# fullname="${account}.dkr.ecr.${region}.amazonaws.com/${algorithm_name}:latest"
#
# # If the repository doesn't exist in ECR, create it.
#
# aws ecr describe-repositories --repository-names "${algorithm_name}" > /dev/null 2>&1
#
# if [ $? -ne 0 ]
# then
#     aws ecr create-repository --repository-name "${algorithm_name}" > /dev/null
# fi
#
# # Get the login command from ECR in order to pull down the SageMaker PyTorch image
# aws ecr get-login-password --region us-east-1 | docker login --username AWS --password-stdin 763104351884.dkr.ecr.us-east-1.amazonaws.com
# # Build the docker image locally with the image name and then push it to ECR
# # with the full name.
# docker build  -t ${algorithm_name} . --build-arg REGION=${region}
# docker tag ${algorithm_name} ${fullname}
#
# # Get the login command from ECR and execute it directly
# aws ecr get-login-password --region ${region} | docker login --username AWS --password-stdin ${account}.dkr.ecr.${region}.amazonaws.com
# docker push ${fullname}

# %% [markdown]
# ## Deploy Container and run inference based on the pretrained model

# %% [markdown]
# To deploy a pretrained PyTorch model, you'll need to use the PyTorch estimator object to create a PyTorchModel object and set a different entry_point.
#
# You'll use the PyTorchModel object to deploy a PyTorchPredictor. This creates a SageMaker Endpoint -- a hosted prediction service that we can use to perform inference.

# %%
import sys

# !{sys.executable} -m pip install Transformers

# %%
import os
import boto3
import sagemaker

role = sagemaker.get_execution_role()
sess = sagemaker.Session()

bucket = sess.default_bucket()
prefix = "inf1_compiled_model/model"

# Get container name in ECR
client=boto3.client('sts')
account=client.get_caller_identity()['Account']

my_session=boto3.session.Session()
region=my_session.region_name

algorithm_name="neuron-py36-inference"
ecr_image='{}.dkr.ecr.{}.amazonaws.com/{}:latest'.format(account, region, algorithm_name)
print(ecr_image)

# %% [markdown]
# An implementation of *model_fn* is required for inference script.
# We are going to implement our own **model_fn** and **predict_fn** for Hugging Face Bert, and use default implementations of **input_fn** and **output_fn** defined in sagemaker-pytorch-containers.
#
# In this example, the inference script is put in ***code*** folder. Run the next cell to see it:

# %%
# !pygmentize code/inference.py

# %% [markdown]
# Path of compiled pretrained model in S3:

# %%
key = os.path.join(prefix, "model.tar.gz")
pretrained_model_data = "s3://{}/{}".format(bucket, key)
print(pretrained_model_data)

# %% [markdown]
# The model object is defined by using the SageMaker Python SDK's PyTorchModel and pass in the model from the estimator and the entry_point. The endpoint's entry point for inference is defined by model_fn as seen in the previous code block that prints out **inference.py**. The model_fn function will load the model and required tokenizer.
#
# Note, **image_uri** must be user's own ECR images.

# %%
from sagemaker.pytorch.model import PyTorchModel

pytorch_model = PyTorchModel(
    model_data=pretrained_model_data,
    role=role,
    source_dir="code",
    framework_version="1.7.1",
    entry_point="inference.py",
    image_uri=ecr_image
)

# Let SageMaker know that we've already compiled the model via neuron-cc
pytorch_model._is_compiled_model = True

# %% [markdown]
# The arguments to the deploy function allow us to set the number and type of instances that will be used for the Endpoint.
#
# Here you will deploy the model to a single **ml.inf1.2xlarge** instance.
# It may take 6-10 min to deploy.

# %%
# %%time

predictor = pytorch_model.deploy(initial_instance_count=1, instance_type="ml.inf1.2xlarge")

# %%
print(predictor.endpoint_name)

# %% [markdown]
# Since in the input_fn we declared that the incoming requests are json-encoded, we need to use a json serializer, to encode the incoming data into a json string. Also, we declared the return content type to be json string, we Need to use a json deserializer to parse the response.

# %%
predictor.serializer = sagemaker.serializers.JSONSerializer()
predictor.deserializer = sagemaker.deserializers.JSONDeserializer()

# %% [markdown]
# Using a list of sentences, now SageMaker endpoint is invoked to get predictions.

# %%
# %%time
result = predictor.predict(
    [
        "Never allow the same bug to bite you twice.",
        "The best part of Amazon SageMaker is that it makes machine learning easy.",
    ]
)
print(result)

# %%
# %%time
result = predictor.predict(
    [
        "The company HuggingFace is based in New York City",
        "HuggingFace's headquarters are situated in Manhattan",
    ]
)
print(result)

# %% [markdown]
# ## Benchmarking your endpoint
#
# The following cells create a load test for your endpoint. You first define some helper functions: `inference_latency` runs the endpoint request, collects cliend side latency and any errors, `random_sentence` builds random to be sent to the endpoint.

# %%
import numpy as np 
import datetime
import math
import time
import boto3   
import matplotlib.pyplot as plt
from joblib import Parallel, delayed
import numpy as np
from tqdm import tqdm
import random

# %%
def inference_latency(model,*inputs):
    """
    infetence_time is a simple method to return the latency of a model inference.

        Parameters:
            model: torch model onbject loaded using torch.jit.load
            inputs: model() args

        Returns:
            latency in seconds
    """
    error = False
    start = time.time()
    try:
        results = model(*inputs)
    except:
        error = True
        results = []
    return {'latency':time.time() - start, 'error': error, 'result': results}

# %%
def random_sentence():
    
    s_nouns = ["A dude", "My mom", "The king", "Some guy", "A cat with rabies", "A sloth", "Your homie", "This cool guy my gardener met yesterday", "Superman"]
    p_nouns = ["These dudes", "Both of my moms", "All the kings of the world", "Some guys", "All of a cattery's cats", "The multitude of sloths living under your bed", "Your homies", "Like, these, like, all these people", "Supermen"]
    s_verbs = ["eats", "kicks", "gives", "treats", "meets with", "creates", "hacks", "configures", "spies on", "retards", "meows on", "flees from", "tries to automate", "explodes"]
    p_verbs = ["eat", "kick", "give", "treat", "meet with", "create", "hack", "configure", "spy on", "retard", "meow on", "flee from", "try to automate", "explode"]
    infinitives = ["to make a pie.", "for no apparent reason.", "because the sky is green.", "for a disease.", "to be able to make toast explode.", "to know more about archeology."]
    
    return (random.choice(s_nouns) + ' ' + random.choice(s_verbs) + ' ' + random.choice(s_nouns).lower() or random.choice(p_nouns).lower() + ' ' + random.choice(infinitives))

print([random_sentence(), random_sentence()])

# %% [markdown]
# The following cell creates `number_of_clients` concurrent threads to run `number_of_runs` requests. Once completed, a `boto3` CloudWatch client will query for the server side latency metrics for comparison.

# %%
# Defining Auxiliary variables
number_of_clients = 2
number_of_runs = 1000
t = tqdm(range(number_of_runs),position=0, leave=True)

# Starting parallel clients
cw_start = datetime.datetime.utcnow()

results = Parallel(n_jobs=number_of_clients,prefer="threads")(delayed(inference_latency)(predictor.predict,[random_sentence(), random_sentence()]) for mod in t)
avg_throughput = t.total/t.format_dict['elapsed']

cw_end = datetime.datetime.utcnow() 

# Computing metrics and print
latencies = [res['latency'] for res in results]
errors = [res['error'] for res in results]
error_p = sum(errors)/len(errors) *100
p50 = np.quantile(latencies[-1000:],0.50) * 1000
p90 = np.quantile(latencies[-1000:],0.95) * 1000
p95 = np.quantile(latencies[-1000:],0.99) * 1000

print(f'Avg Throughput: :{avg_throughput:.1f}\n')
print(f'50th Percentile Latency:{p50:.1f} ms')
print(f'90th Percentile Latency:{p90:.1f} ms')
print(f'95th Percentile Latency:{p95:.1f} ms\n')
print(f'Errors percentage: {error_p:.1f} %\n')

# Querying CloudWatch
print('Getting Cloudwatch:')
cloudwatch = boto3.client('cloudwatch')
statistics=['SampleCount', 'Average', 'Minimum', 'Maximum']
extended=['p50', 'p90', 'p95', 'p100']

# Give 5 minute buffer to end
cw_end += datetime.timedelta(minutes=5)

# Period must be 1, 5, 10, 30, or multiple of 60
# Calculate closest multiple of 60 to the total elapsed time
factor = math.ceil((cw_end - cw_start).total_seconds() / 60)
period = factor * 60
print('Time elapsed: {} seconds'.format((cw_end - cw_start).total_seconds()))
print('Using period of {} seconds\n'.format(period))

cloudwatch_ready = False
# Keep polling CloudWatch metrics until datapoints are available
while not cloudwatch_ready:
  time.sleep(30)
  print('Waiting 30 seconds ...')
  # Must use default units of microseconds
  model_latency_metrics = cloudwatch.get_metric_statistics(MetricName='ModelLatency',
                                             Dimensions=[{'Name': 'EndpointName',
                                                          'Value': predictor.endpoint_name},
                                                         {'Name': 'VariantName',
                                                          'Value': "AllTraffic"}],
                                             Namespace="AWS/SageMaker",
                                             StartTime=cw_start,
                                             EndTime=cw_end,
                                             Period=period,
                                             Statistics=statistics,
                                             ExtendedStatistics=extended
                                             )
  # Should be 1000
  if len(model_latency_metrics['Datapoints']) > 0:
    print('{} latency datapoints ready'.format(model_latency_metrics['Datapoints'][0]['SampleCount']))
    side_avg = model_latency_metrics['Datapoints'][0]['Average'] / number_of_runs
    side_p50 = model_latency_metrics['Datapoints'][0]['ExtendedStatistics']['p50'] / number_of_runs
    side_p90 = model_latency_metrics['Datapoints'][0]['ExtendedStatistics']['p90'] / number_of_runs
    side_p95 = model_latency_metrics['Datapoints'][0]['ExtendedStatistics']['p95'] / number_of_runs
    side_p100 = model_latency_metrics['Datapoints'][0]['ExtendedStatistics']['p100'] / number_of_runs
    
    print(f'50th Percentile Latency:{side_p50:.1f} ms')
    print(f'90th Percentile Latency:{side_p90:.1f} ms')
    print(f'95th Percentile Latency:{side_p95:.1f} ms\n')

    cloudwatch_ready = True

# %% [markdown]
# ### Cleanup
# Endpoints should be deleted when no longer in use, to avoid costs.

# %%
predictor.delete_endpoint(predictor.endpoint)
